# %% [markdown]
# 무더위쉼터 정보 조회

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

skey = 'exjN0u0fcaDqhOp9QwJibk%2FcLDOo%2FbDzOjs%2FKWIr3J9xfar8OuhqWNN7GHP1w%2BKbWZazL5uHba1P%2FnBGGO7Q8Q%3D%3D'

stype = 'json'




url = 'http://apis.data.go.kr/1741000/HeatWaveShelter2/getHeatWaveShelterList2'
params = f'?ServiceKey={skey}&type={stype}&areaCd=1111051000'
query = url + params


request = Request(query)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
# print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
# items = response_dict['row']
items = response_dict['HeatWaveShelter'][1]['row']
df = pd.DataFrame(items)
df
# Out:
#   restSeqNo  year      areaCd equptype      restname  \
# 0     11708  2013  1111051000      005     청운효자동주민센터
# 1     11300  2013  1111051000      001       인왕산정경로당
# 2     11289  2013  1111051000      001         청운경로당
# 3        60  2014  1111051000      005     청운효자동주민센터
# 4         1  2014  1111051000      001         청운경로당
# 5        77  2014  1111051000      001  6.25참전유공자경로당
# 6        78  2014  1111051000      001       인왕산정경로당
# 7         1  2015  1111051000      005     청운효자동주민센터
# 8        20  2015  1111051000      001         청운경로당
# 9        38  2016  1111051000      005     청운효자동주민센터
#
#                                          restaddr              creDttm  \
# 0                     서울특별시 종로구  자하문로  92   (궁정동)  2013-07-04 15:15:55
# 1                     서울특별시 종로구  필운대로  86   (신교동)  2013-04-12 17:09:51
# 2                     서울특별시 종로구  필운대로  86   (신교동)  2013-04-12 17:08:19
# 3           서울특별시 종로구  자하문로  92 , 청운효자동주민센터 (궁정동)  2014-05-02 19:08:09
# ...

# %%
skey = 'exjN0u0fcaDqhOp9QwJibk%2FcLDOo%2FbDzOjs%2FKWIr3J9xfar8OuhqWNN7GHP1w%2BKbWZazL5uHba1P%2FnBGGO7Q8Q%3D%3D'

stype = 'json'




url = 'http://apis.data.go.kr/1741000/HeatWaveShelter2/getHeatWaveShelterList2'
params = f'?ServiceKey={skey}&type={stype}&areaCd=1111051000'
query = url + params


request = Request(query)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
# print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
# items = response_dict['row']
items = response_dict['HeatWaveShelter'][1]['row']
df = pd.DataFrame(items)
df
# Out:
#   restSeqNo  year      areaCd equptype      restname  \
# 0     11708  2013  1111051000      005     청운효자동주민센터
# 1     11300  2013  1111051000      001       인왕산정경로당
# 2     11289  2013  1111051000      001         청운경로당
# 3        60  2014  1111051000      005     청운효자동주민센터
# 4         1  2014  1111051000      001         청운경로당
# 5        77  2014  1111051000      001  6.25참전유공자경로당
# 6        78  2014  1111051000      001       인왕산정경로당
# 7         1  2015  1111051000      005     청운효자동주민센터
# 8        20  2015  1111051000      001         청운경로당
# 9        38  2016  1111051000      005     청운효자동주민센터
#
#                                          restaddr              creDttm  \
# 0                     서울특별시 종로구  자하문로  92   (궁정동)  2013-07-04 15:15:55
# 1                     서울특별시 종로구  필운대로  86   (신교동)  2013-04-12 17:09:51
# 2                     서울특별시 종로구  필운대로  86   (신교동)  2013-04-12 17:08:19
# 3           서울특별시 종로구  자하문로  92 , 청운효자동주민센터 (궁정동)  2014-05-02 19:08:09
# ...

# %%
response_dict
# Out:
# {'HeatWaveShelter': [{'head': [{'totalCount': 458467},
#     {'numOfRows': '100', 'pageNo': '1', 'type': 'JSON'},
#     {'RESULT': {'resultCode': 'INFO-0', 'resultMsg': 'NOMAL SERVICE'}}]},
#   {'row': [{'restSeqNo': '199',
#      'year': '2013',
#      'areaCd': '4822033000',
#      'equptype': '008',
#      'restname': '광도농협도산지소',
#      'restaddr': None,
#      'creDttm': '2013-05-07 16:37:52',
#      'updtDttm': None,
#      'useYn': None,
#      'areaNm': '경상남도 통영시 도산면  ',
#      'operBeginDe': None,
#      'operEndDe': None,
#      'ar': 200,
#      'usePsblNmpr': 50,
#      'colrHoldElefn': 0,
#      'colrHoldArcndtn': 2,
#      'chckMatterNightOpnAt': 'Y',
#      'chckMatterWkendHdayOpnAt': 'Y',
#      'chckMatterStayngPsblAt': None,
#      'rm': None,
#      'dtlAdres': '법송리',
#      'mngdpt_cd': None,
#      'mngdptCd': None,
#      'xcord': None,
#      'ycord': None,
#      'la': None,
#      'lo': None},
#     {'restSeqNo': '199',
#      'year': '2013',
# ...

# %%
  stype = 'json'
    url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
    params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&'+ encode
    query = url + params

# %%
url = 'http://apis.data.go.kr/1741000/HeatWaveCasualtiesRegion/getHeatWaveCasualtiesRegionList?ServiceKey=exjN0u0fcaDqhOp9QwJibk%2FcLDOo%2FbDzOjs%2FKWIr3J9xfar8OuhqWNN7GHP1w%2BKbWZazL5uHba1P%2FnBGGO7Q8Q%3D%3D&type=json&pageNo=1&numOfRows=3&bas_yy=2019'

request = Request(url)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
# response_dict = json.loads(response_body.decode('utf-8'))

response_dict = json.loads(response_body.decode('utf-8'))
# items = response_dict['row']
items = response_dict['HeatWaveCasualtiesRegion'][1]['row']
df = pd.DataFrame(items)
df
# Out:
#   bas_yy regi   tot otdoor_subtot otdoor_otdoor_wrkpl otdoor_field  \
# 0   2019   합계  1841          1476                 596          126
# 1   2019   서울   116            85                  36           16
# 2   2019   부산   100            85                  47            6
#
#   otdoor_farmland otdoor_mountain otdoor_river otdoor_road  \
# 0             269              58           28         198
# 1               3               2            0          19
# 2               5               2            3          12
#
#   otdoor_resarea_arund otdoor_etc indoor_subtot indoor_house indoor_bildg  \
# 0                   75        126           365          121           48
# 1                    5          4            31           15            5
# 2                    3          7            15            3            0
#
#   indoor_wrkpl indoor_greenhouse indoor_etc
# 0          125                27         44
# 1            8                 0          3
# ...
