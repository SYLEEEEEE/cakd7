# %%
import pandas as pd

df = pd.read_csv('./서울시 무더위쉼터.csv', encoding='cp949')
df
# Out:
#             시설번호    년도        지역코드  시설유형         쉼터명칭                   도로명주소  \
# 0     1120000293  2022  1120064500    13   옥수나들목 샘물창고  서울특별시 성동구 동호로 21 (옥수동)
# 1     1129000257  2022  1129057500     1    동선동 희망경로당   서울특별시 성북구 아리랑로4길 49-1
# 2     1121500101  2022  1121577000    11        긴고랑공원                     NaN
# 3     1121500105  2022  1121583000    11        금모래공원     서울특별시 광진구 뚝섬로56길 28
# 4     1120000292  2022  1120010700    12   무지개텃밭 샘물창고                     NaN
# ...          ...   ...         ...   ...          ...                     ...
# 4090  1156000150  2022  1156065000     1  우성1차아파트 경로당       서울특별시 영등포구 도신로 68
# 4091  1156000152  2022  1156065000     1     건영아파트경로당      서울특별시 영등포구 도림로 313
# 4092    11215012  2022  1121573000     2    광진노인종합복지관        서울특별시 광진구 군자로 88
# 4093    11215070  2022  1121584000     2    자양종합사회복지관      서울특별시 광진구 자양번영로 35
# 4094  1121500098  2022  1121573000    12         군자공원     서울특별시 광진구 동일로52길 27
#
# ...

# %%
# 서울시 무더위쉼터 정보 컬럼
df.columns
# Out:
# Index(['시설번호', '년도', '지역코드', '시설유형', '쉼터명칭', '도로명주소', '지번상세주소', '면적', '이용가능인원',
#        '선풍기보유대수', '에어컨보유대수', '야간개방', '휴일개방', '숙박가능여부', '입력시간', '수정시간', '사용여부',
#        '비고', '운영시작일', '운영종료일', '경도', '위도', 'X좌표', 'Y좌표'],
#       dtype='object')

# %%
df1 = df[['시설번호','지역코드','도로명주소','이용가능인원','위도','경도']]
df1
# Out:
#             시설번호        지역코드                   도로명주소  이용가능인원         위도  \
# 0     1120000293  1120064500  서울특별시 성동구 동호로 21 (옥수동)       8  37.539900
# 1     1129000257  1129057500   서울특별시 성북구 아리랑로4길 49-1      42  37.595875
# 2     1121500101  1121577000                     NaN      15  37.558969
# 3     1121500105  1121583000     서울특별시 광진구 뚝섬로56길 28      15  37.530181
# 4     1120000292  1120010700                     NaN       5  37.553600
# ...          ...         ...                     ...     ...        ...
# 4090  1156000150  1156065000       서울특별시 영등포구 도신로 68      50  37.505763
# 4091  1156000152  1156065000      서울특별시 영등포구 도림로 313      25  37.504310
# 4092    11215012  1121573000        서울특별시 광진구 군자로 88     500  37.551075
# 4093    11215070  1121584000      서울특별시 광진구 자양번영로 35      46  37.532894
# 4094  1121500098  1121573000     서울특별시 광진구 동일로52길 27      15  37.554369
#
#               경도
# 0     127.017200
# 1     127.018283
# 2     127.090956
# 3     127.082398
# ...

# %%
df2 = df1.dropna()  # 결측치 제거
df2
# Out:
#             시설번호        지역코드                   도로명주소  이용가능인원         위도  \
# 0     1120000293  1120064500  서울특별시 성동구 동호로 21 (옥수동)       8  37.539900
# 1     1129000257  1129057500   서울특별시 성북구 아리랑로4길 49-1      42  37.595875
# 3     1121500105  1121583000     서울특별시 광진구 뚝섬로56길 28      15  37.530181
# 6     1121500106  1121584000    서울특별시 광진구 자양번영로3길 16      15  37.531990
# 8       11590079  1159058000  서울특별시 동작구 서달로 91 (흑석동)      80  37.502233
# ...          ...         ...                     ...     ...        ...
# 4090  1156000150  1156065000       서울특별시 영등포구 도신로 68      50  37.505763
# 4091  1156000152  1156065000      서울특별시 영등포구 도림로 313      25  37.504310
# 4092    11215012  1121573000        서울특별시 광진구 군자로 88     500  37.551075
# 4093    11215070  1121584000      서울특별시 광진구 자양번영로 35      46  37.532894
# 4094  1121500098  1121573000     서울특별시 광진구 동일로52길 27      15  37.554369
#
#               경도
# 0     127.017200
# 1     127.018283
# 3     127.082398
# 6     127.074347
# ...

# %%
df2.isnull().sum() # 결측치 확인
# Out:
# 시설번호      0
# 지역코드      0
# 도로명주소     0
# 이용가능인원    0
# 위도        0
# 경도        0
# dtype: int64

# %%
df2
# Out:
#             시설번호        지역코드                   도로명주소  이용가능인원         위도  \
# 0     1120000293  1120064500  서울특별시 성동구 동호로 21 (옥수동)       8  37.539900
# 1     1129000257  1129057500   서울특별시 성북구 아리랑로4길 49-1      42  37.595875
# 3     1121500105  1121583000     서울특별시 광진구 뚝섬로56길 28      15  37.530181
# 6     1121500106  1121584000    서울특별시 광진구 자양번영로3길 16      15  37.531990
# 8       11590079  1159058000  서울특별시 동작구 서달로 91 (흑석동)      80  37.502233
# ...          ...         ...                     ...     ...        ...
# 4090  1156000150  1156065000       서울특별시 영등포구 도신로 68      50  37.505763
# 4091  1156000152  1156065000      서울특별시 영등포구 도림로 313      25  37.504310
# 4092    11215012  1121573000        서울특별시 광진구 군자로 88     500  37.551075
# 4093    11215070  1121584000      서울특별시 광진구 자양번영로 35      46  37.532894
# 4094  1121500098  1121573000     서울특별시 광진구 동일로52길 27      15  37.554369
#
#               경도
# 0     127.017200
# 1     127.018283
# 3     127.082398
# 6     127.074347
# ...

# %%
import re
import warnings
warnings.filterwarnings('ignore')
df3 = df2.copy()
df3['도로명주소'] = df2['도로명주소'].str.extract(r'(\w+구)')
df3
# Out:
#             시설번호        지역코드 도로명주소  이용가능인원         위도          경도
# 0     1120000293  1120064500   성동구       8  37.539900  127.017200
# 1     1129000257  1129057500   성북구      42  37.595875  127.018283
# 3     1121500105  1121583000   광진구      15  37.530181  127.082398
# 6     1121500106  1121584000   광진구      15  37.531990  127.074347
# 8       11590079  1159058000   동작구      80  37.502233  126.958566
# ...          ...         ...   ...     ...        ...         ...
# 4090  1156000150  1156065000  영등포구      50  37.505763  126.899790
# 4091  1156000152  1156065000  영등포구      25  37.504310  126.901045
# 4092    11215012  1121573000   광진구     500  37.551075  127.071497
# 4093    11215070  1121584000   광진구      46  37.532894  127.075196
# 4094  1121500098  1121573000   광진구      15  37.554369  127.072801
#
# [4030 rows x 6 columns]

# %%
df3.set_index('도로명주소', inplace = True)  # 도로명주소 인덱스로

# %%
df3
# Out:
#              시설번호        지역코드  이용가능인원         위도          경도
# 도로명주소
# 성동구    1120000293  1120064500       8  37.539900  127.017200
# 성북구    1129000257  1129057500      42  37.595875  127.018283
# 광진구    1121500105  1121583000      15  37.530181  127.082398
# 광진구    1121500106  1121584000      15  37.531990  127.074347
# 동작구      11590079  1159058000      80  37.502233  126.958566
# ...           ...         ...     ...        ...         ...
# 영등포구   1156000150  1156065000      50  37.505763  126.899790
# 영등포구   1156000152  1156065000      25  37.504310  126.901045
# 광진구      11215012  1121573000     500  37.551075  127.071497
# 광진구      11215070  1121584000      46  37.532894  127.075196
# 광진구    1121500098  1121573000      15  37.554369  127.072801
#
# [4030 rows x 5 columns]

# %%
gu = df3.groupby('도로명주소')
list(gu)
# Out:
# [('강남구',
#                시설번호        지역코드  이용가능인원         위도          경도
#   도로명주소
#   강남구    1168000099  1168056500       7  37.519266  127.047838
#   강남구      11680019  1168054500      10  37.526595  127.037474
#   강남구      11680012  1168054000      30  37.530618  127.030651
#   강남구      11680014  1168054000      20  37.525176  127.044256
#   강남구      11680016  1168054000      30  37.509863  127.051901
#   ...           ...         ...     ...        ...         ...
#   강남구      11680056  1168067000      30  37.484087  127.077966
#   강남구      11680030  1168060000      35  37.502833  127.062011
#   강남구      11680027  1168060000      30  37.493156  127.062999
#   강남구    1168000103  1168066000      20  37.484546  127.054616
#   강남구      11680049  1168065600      25  37.489931  127.050699
#
#   [78 rows x 5 columns]),
#  ('강동구',
#              시설번호        지역코드  이용가능인원         위도          경도
#   도로명주소
#   강동구    11740247  1174070000      44  37.533037  127.146135
# ...

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings('ignore')

# %%
from time import sleep
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import re
import urllib



path = 'C:/cakd7/tool/chromedriver.exe'
driver = webdriver.Chrome(path)

# url='https://earth.google.com/web/search/'

adress = urllib.parse.quote('서울특별시 성동구 동호로 21 (옥수동)')
wg =f'37.539900,127.017200'                           # @'+wg+'


driver = webdriver.Chrome(path)
driver.maximize_window()
driver.implicitly_wait(time_to_wait=10)

driver.get(url='https://earth.google.com/web/search/'+adress+'/@'+wg+'21.89101966a,23230.14612967d,1y,-0h,0t,0r/data=CigiJgokCcS5EpajwjRAEcS5EpajwjTAGW9cSl8sjklAISd7z0p-tknA')
