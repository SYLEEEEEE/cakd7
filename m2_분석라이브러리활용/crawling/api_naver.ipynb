# %% [markdown]
# # 네이버 검색 API 서비스

# %% [markdown]
# ## 블로그

# %%
import os
import sys
import urllib.request
client_id = "nqNfbjNj0cAxRmlPMbS7"
client_secret = "vypKmBjPTr"

query = urllib.parse.quote(input("검색어 : "))
# url = "https://openapi.naver.com/v1/search/blog?query=" + query # json 결과
url = "https://openapi.naver.com/v1/search/blog.xml?query=" + query # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색어 : 빅데이터
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup as bsp
xml = response_body.decode('utf-8')
bs = bsp(xml, 'lxml')

bs.get_text()
# Out:
# '{\n\t"lastBuildDate":"Thu, 28 Jul 2022 10:43:07 +0900",\n\t"total":1144656,\n\t"start":1,\n\t"display":10,\n\t"items":[\n\t\t{\n\t\t\t"title":"빅데이터<\\/b>전문가 준비를 위한 체계적인 방법",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/nam8853nam?Redirect=Log&logNo=222802704648",\n\t\t\t"description":"그 중에서도 주목해 볼만한 분야가 바로 ‘빅데이터<\\/b>’ 라고 생각했어요. 기업이 이익을 창출하기... 이런 점들을 고려했을 때 1) 영업, 2) 컨설팅, 3) 제조 분야 모두 통틀어서 데이터 분석이 정말 중요한 부분을... ",\n\t\t\t"bloggername":"율맘 스토리",\n\t\t\t"bloggerlink":"https:\\/\\/blog.naver.com\\/nam8853nam",\n\t\t\t"postdate":"20220707"\n\t\t},\n\t\t{\n\t\t\t"title":"빅데이터<\\/b>분석기사 실기 준비를 위한 학습루틴",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/parkrapp?Redirect=Log&logNo=222753783578",\n\t\t\t"description":"안녕하세요, 오늘은 제가 도전한 빅데이터<\\/b>분석기사에 대한 정보를 많은 분과 나누고 싶어 이야기를... 빅데이터<\\/b>를 이해하고 이를 분석, 수집, 저장 등의 시각화를 수행하는 실무자 역할을 하는 분석기사는... ",\n\t\t\t"bloggername":"황금빛 쭈롱월드",\n\t\t\t"bloggerlink":"https:\\/\\/blog.naver.com\\/parkrapp",\n\t\t\t"postdate":"20220531"\n\t\t},\n\t\t{\n\t\t\t"title":"
# ...

# %%
import os
import sys
import urllib.request
client_id = "nqNfbjNj0cAxRmlPMbS7"
client_secret = "vypKmBjPTr"

query = urllib.parse.quote(input("검색어 : "))
url = "https://openapi.naver.com/v1/search/blog?query=" + query # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + query # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색어 : 빅데이터
# {
# 	"lastBuildDate":"Fri, 29 Jul 2022 09:11:11 +0900",
# 	"total":1144603,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>빅데이터<\/b>전문가 준비를 위한 체계적인 방법",
# 			"link":"https:\/\/blog.naver.com\/nam8853nam?Redirect=Log&logNo=222802704648",
# 			"description":"그 중에서도 주목해 볼만한 분야가 바로 ‘<b>빅데이터<\/b>’ 라고 생각했어요. 기업이 이익을 창출하기... 이런 점들을 고려했을 때 1) 영업, 2) 컨설팅, 3) 제조 분야 모두 통틀어서 데이터 분석이 정말 중요한 부분을... ",
# 			"bloggername":"율맘 스토리",
# 			"bloggerlink":"https:\/\/blog.naver.com\/nam8853nam",
# 			"postdate":"20220707"
# 		},
# 		{
# 			"title":"<b>빅데이터<\/b>분석기사 실기 준비를 위한 학습루틴",
# 			"link":"https:\/\/blog.naver.com\/parkrapp?Redirect=Log&logNo=222753783578",
# 			"description":"안녕하세요, 오늘은 제가 도전한 <b>빅데이터<\/b>분석기사에 대한 정보를 많은 분과 나누고 싶어 이야기를... <b>빅데이터<\/b>를 이해하고 이를 분석, 수집, 저장 등의 시각화를 수행하는 실무자 역할을 하는 분석기사는... ",
# 			"bloggername":"황금빛 쭈롱월드",
# 			"bloggerlink":"https:\/\/blog.naver.com\/parkrapp",
# 			"postdate":"20220531"
# 		},
# 		{
# ...

# %% [markdown]
# #### Q. 네이버 웹문서에서 빅데이터에 대한 데이터를 가져와서 데이터프레임으로 출력하세요( api 가이드 참조)

# %%
import pandas as pd
from bs4 import BeautifulSoup as bsp
import urllib.request
import pandas as pd


query = urllib.parse.quote("빅데이터")
url = f'https://openapi.naver.com/v1/search/webkr.json?query={query}&display=10&start=1'  # json
# url = f"https://openapi.naver.com/v1/search/webkr.xml?query={query}&display=10&start=1"  # xml
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
#     print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

df = pd.read_json(response_body.decode('utf-8'))

df1 = pd.DataFrame(columns=['title', 'description', 'link'])
df1
for i in range(10):
    df1.loc[i] = [df['items'][i]['title'], df['items'][i]['description'], df['items'][i]['link']]
import re
for j in range(10):
    df1.title[j] = re.sub('[<br></br>]',' ', df1.title[j])
    df1.description[j] = re.sub('[<br></br>]',' ', df1.description[j])
     
df1
# Out:
#                                                title  \
# 0                              빅 데이터     프로세싱 - 나무위키
# 1      빅데이터    란? | 고급    빅데이터     분석 | SAP Insights
# 2                    빅 데이터    란 무엇입니까? | O acle 대한민국
# 3      빅데이터    ( ig data) 이해 - 정의, 분석, 기술, 특징, 사례 연구
# 4                                    네이버    데이터    랩
# 5                                    빅데이터     - BC카드
# 6  트라이빅 소개 &lt; 서비스 안내 : KOTRA 무역투자   빅데이터     - ...
# 7             국가기술    빅데이터     분석기사 -    데이터    자격시험
# 8                   빅데이터    의 이해 - 글이 작품이 되는 공간, 브런치
# 9                      미디어백과:    빅데이터     - 네이버 지식백과
#
#                                          description  \
# 0  Big data p ocessing 디지털 시대에서 폭증하는 '방대한 양의    데...
# 1  비즈니스에 대한 360도 통찰을 제공하고 디지털 노이즈 속에 숨은 성장 기회를 찾도...
# 2     빅데이터    는 특히 새로운    데이터     소스에서 나온 더 크고 더 ...
# 3     빅데이터    ( ig data)란 기존    데이터     프로세싱 방식을 ...
# 4        네이버의 검색 트렌드 및 급상승검색어 이력, 쇼핑 카테고리별 검색 트렌드 제공
# 5  fn igdata.com    빅데이터     생태계 조성 기반 마련,    빅데이...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   lastBuildDate  10 non-null     object
#  1   total          10 non-null     int64
#  2   start          10 non-null     int64
#  3   display        10 non-null     int64
#  4   items          10 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 528.0+ bytes

# %%
import os
import sys
import urllib.request

query = urllib.parse.quote("빅데이터")
url = 'https://openapi.naver.com/v1/search/webkr.json?query='+query # json 결과
# url = "https://openapi.naver.com/v1/search/webkr.json?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

df = pd.read_json(response_body.decode('utf-8'))
df

# %% [markdown]
# #### 0728_1 과제
# 웹문서에서 빅데이터에 대한 의미있는 정보로 구성된 데이터프레임을 출력하세요

# %%
import pandas as pd
from bs4 import BeautifulSoup as bsp
import urllib.request
import pandas as pd


query = urllib.parse.quote("빅데이터")
url = f'https://openapi.naver.com/v1/search/webkr.json?query={query}&display=10&start=1'  # json
# url = f"https://openapi.naver.com/v1/search/webkr.xml?query={query}&display=10&start=1"  # xml
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
#     print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

df = pd.read_json(response_body.decode('utf-8'))

df1 = pd.DataFrame(columns=['title', 'description', 'link'])
df1
for i in range(10):
    df1.loc[i] = [df['items'][i]['title'], df['items'][i]['description'], df['items'][i]['link']]
import re
for j in range(10):
    df1.title[j] = re.sub('[<br></br>]',' ', df1.title[j])
    df1.description[j] = re.sub('[<br></br>]',' ', df1.description[j])
     
df1
# Out:
#                                                title  \
# 0                              빅 데이터     프로세싱 - 나무위키
# 1      빅데이터    란? | 고급    빅데이터     분석 | SAP Insights
# 2                    빅 데이터    란 무엇입니까? | O acle 대한민국
# 3      빅데이터    ( ig data) 이해 - 정의, 분석, 기술, 특징, 사례 연구
# 4                                    네이버    데이터    랩
# 5                                    빅데이터     - BC카드
# 6  트라이빅 소개 &lt; 서비스 안내 : KOTRA 무역투자   빅데이터     - ...
# 7             국가기술    빅데이터     분석기사 -    데이터    자격시험
# 8                   빅데이터    의 이해 - 글이 작품이 되는 공간, 브런치
# 9                      미디어백과:    빅데이터     - 네이버 지식백과
#
#                                          description  \
# 0  Big data p ocessing 디지털 시대에서 폭증하는 '방대한 양의    데...
# 1  비즈니스에 대한 360도 통찰을 제공하고 디지털 노이즈 속에 숨은 성장 기회를 찾도...
# 2     빅데이터    는 특히 새로운    데이터     소스에서 나온 더 크고 더 ...
# 3     빅데이터    ( ig data)란 기존    데이터     프로세싱 방식을 ...
# 4        네이버의 검색 트렌드 및 급상승검색어 이력, 쇼핑 카테고리별 검색 트렌드 제공
# 5  fn igdata.com    빅데이터     생태계 조성 기반 마련,    빅데이...
# ...

# %% [markdown]
# #### 0728_2 과제
# 뉴스, 영화, 쇼핑, 지식in, 카페글에서 적합한 주제에 대한 데이터를 가져와서 데이터프레임으로 출력하세요.

# %%
import pandas as pd
from bs4 import BeautifulSoup as bsp
import urllib.request



query = urllib.parse.quote(input("검색 질의"))
url = f'https://openapi.naver.com/v1/search/movie.json?query={query}&display=10&start=1'  # json   # 출력건수 10 시작위치 1
# url = f"https://openapi.naver.com/v1/search/webkr.xml?query={query}&display=10&start=1"  # xml
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
#     print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

df = pd.read_json(response_body.decode('utf-8'))
df['items'] # 딕셔너리로 출력
# Out:
# 검색 질의멜로
# 0    {'title': '<b>멜로</b>는 정사다', 'link': 'https://m...
# 1    {'title': '스윙어:막장불륜<b>멜로</b>', 'link': 'https:...
# 2    {'title': '멜리 <b>멜로</b>', 'link': 'https://mov...
# 3    {'title': '홍콩<b>멜로</b>', 'link': 'https://movi...
# 4    {'title': '격한<b>멜로</b>', 'link': 'https://movi...
# 5    {'title': '데모니아- <b>멜로</b>드라마 인 3액츠', 'link': ...
# 6    {'title': '<b>멜로</b>드라마', 'link': 'https://mov...
# 7    {'title': '<b>멜로</b>영화', 'link': 'https://movi...
# 8    {'title': '<b>멜로</b>', 'link': 'https://movie....
# 9    {'title': '드라마 스페셜 - 오월의 <b>멜로</b>', 'link': '...
# Name: items, dtype: object

# %%
df1 = pd.DataFrame(columns=['pubDate','title', 'director','actor', 'userRating'])
df1
for i in range(10):
    df1.loc[i] = [df['items'][i]['pubDate'], df['items'][i]['title'], df['items'][i]['director'], df['items'][i]['actor'], df['items'][i]['userRating']]
import re
for j in range(10):
    df1.title[j] = re.sub('[<br></br>]',' ', df1.title[j])
    
df1
# Out:
#   pubDate                     title            director  \
# 0    2022               멜로    는 정사다              벤자민 킴|
# 1    2018         스윙어:막장불륜   멜로                루이스 스모크|
# 2    2018              멜리    멜로                 줄리안 울프|
# 3    2018               홍콩   멜로                    곽민규|
# 4    2017               격한   멜로                    안성민|
# 5    2016  데모니아-    멜로    드라마 인 3액츠  케이넌 발라데즈|페르난다 치콜렛|
# 6    2015                 멜로    드라마  크리스 노다|켄타나 H. 쿠야스|
# 7    2013                  멜로    영화                한창록|
# 8    2012                    멜로                    이로이|
# 9    2012   드라마 스페셜 - 오월의    멜로                    백상훈|
#
#                      actor userRating
# 0                                0.00
# 1                                0.00
# 2                                0.00
# 3                     곽민규|       0.00
# 4             남연우|민진웅|이혜수|       0.00
# 5                                0.00
# 6                                0.00
# ...

# %% [markdown]
# #### 0728_3 과제
# 아래사항에 유의하여 OpenWeatherMap 날씨정보를 웹 API로 가져와서 출력하세요
# ```
# * https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
# * 개발자 등록을 하고 API 키 발급 받음(https://home.openweathermap.org/users/sign_up)
# * New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
# * 기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)
# * 서울, 토쿄, 뉴욕의 날씨를 가져오는 프로그램 작성(text로 가져와서 json으로 변환하여 일차 출력)
#   - cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
#   - 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
#   - 기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
# * json 포멧으로 출력 데이터를 아래와 같이 가독력 있게 출력(소수점 2번째에서 반올림 처리)
#
# + 도시 = Seoul
# | 날씨 = broken clouds
# | 최저 기온 = -1.0 2
# | 최고 기온 = 2.0 2
# | 습도 = 74
# | 기압 = 1023
# | 풍속 = 0.5
# ```
# https://openweathermap.org/api

# %%
import pandas as pd
from bs4 import BeautifulSoup as bsp
import urllib.request as rq

skey = 'fed00c3a5ab1f86b7e007d4e84df407a'
cities = ["1835847", "1850144", "5039192"]
# cities = ["Seoul,KR", "Tokyo,JP", "New%2()York,US"]
for i in cities:   
#     url = f'https://api.openweathermap.org/data/2.5/weather?id={i}&appid={skey}&units=metric&mode=xml'
    url = f'https://api.openweathermap.org/data/2.5/weather?id={i}&appid={skey}&units=metric&mode=json'
    res = rq.urlopen(url).read()
    bs = bsp(res,'html.parser')
    bs = bs.decode('utf-8')
#     print(bs)
#     df = pd.read_json(bs.decode('utf-8'))
#     df['main']
    print(f'''
    + 도시 = {bs['sys']['name']}
    | 날씨 = {bs['weather']['main']}
    | 최저 기온 = {bs['main']['temp_min']}
    | 최고 기온 = {bs['main']['temp_max']}
    | 습도 = {bs['main']['humidity']}
    | 기압 = {bs['main']['pressure']}
    | 풍속 = {bs['wind']['speed']}
    ''')
# # df = pd.read_json(bs.decode('utf-8'))
# df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 8>()
#      13     bs = bs.decode('utf-8')
#      14 #     print(bs)
#      15 #     df = pd.read_json(bs.decode('utf-8'))
#      16 #     df['main']
#      17     print(f'''
# ---> 18     + 도시 = {bs['sys']['name']}
#      19     | 날씨 = {bs['weather']['main']}
#      20     | 최저 기온 = {bs['main']['temp_min']}
#      21     | 최고 기온 = {bs['main']['temp_max']}
#      22     | 습도 = {bs['main']['humidity']}
#      23     | 기압 = {bs['main']['pressure']}
#      24     | 풍속 = {bs['wind']['speed']}
#      25     ''')
#
# TypeError: string indices must be integers

# %%
print(bs.decode('utf-8'))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <weatherdata>
#  <location>
#   <name>
#    Ny
#   </name>
#   <type>
#   </type>
#   <country>
#    BE
#   </country>
#   <timezone>
#    7200
#   </timezone>
#   <location altitude="0" geobase="geonames" geobaseid="2791745" latitude="50.2856" longitude="5.4815">
#   </location>
#  </location>
#  <credit>
#  </credit>
#  <meta/>
#  <lastupdate>
#  </lastupdate>
#  <calctime>
#   0
#  </calctime>
#  <nextupdate>
#  </nextupdate>
#  <sun rise="2022-07-28T04:00:25" set="2022-07-28T19:28:29">
#  </sun>
#  <forecast>
#   <time from="2022-07-28T15:00:00" to="2022-07-28T18:00:00">
#    <symbol name="온흐림" number="804" var="04d">
#    </symbol>
#    <precipitation probability="0">
#    </precipitation>
#    <winddirection code="NNE" deg="23" name="North-northeast">
#    </winddirection>
#    <windspeed mps="2.34" name="Light breeze" unit="m/s">
#    </windspeed>
#    <windgust gust="3.72" unit="m/s">
#    </windgust>
# ...

# %% [markdown]
# # 공공데이터 API

# %% [markdown]
# ## 상가업소정보

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

skey = 'exjN0u0fcaDqhOp9QwJibk%2FcLDOo%2FbDzOjs%2FKWIr3J9xfar8OuhqWNN7GHP1w%2BKbWZazL5uHba1P%2FnBGGO7Q8Q%3D%3D'
res_id = 'storezone'
stype = 'json'




url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&'+ urlencode({quote_plus('key'):'9174'})
query = url + params
print(query)

request = Request(query)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
# print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
items = response_dict['body']['items']

df = pd.DataFrame(items)
df
# Out:
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?ServiceKey=exjN0u0fcaDqhOp9QwJibk%2FcLDOo%2FbDzOjs%2FKWIr3J9xfar8OuhqWNN7GHP1w%2BKbWZazL5uHba1P%2FnBGGO7Q8Q%3D%3D&type=json&resId=storezone&key=9174
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9174        인사동       11    서울특별시    11110      종로구    226875        21
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((126.986059148338 37.5765234907...  2021-06-30

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

def baro_api(skey, res_id, encode):
    
    stype = 'json'
    url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
    params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&'+ encode
    query = url + params
    
    request = Request(query)
    request.get_method = lambda: 'GET'
    response_body = urlopen(request).read()
        
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['body']['items']
    df = pd.DataFrame(items)
    return df

# %% [markdown]
# ## 상권조회

# %% [markdown]
# ### 지정상권 조회

# %%
skey = 'exjN0u0fcaDqhOp9QwJibk%2FcLDOo%2FbDzOjs%2FKWIr3J9xfar8OuhqWNN7GHP1w%2BKbWZazL5uHba1P%2FnBGGO7Q8Q%3D%3D'
res_id = 'storezone'
encode = urlencode({quote_plus('key'):'9193'})

baro_api(skey, res_id, encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30

# %% [markdown]
# ### 반경 내 상권 조회

# %%
encode = urlencode({quote_plus('catId'):'radius', quote_plus('radius'):'500', quote_plus('cx'):'127.004528', quote_plus('cy'):'37.567538'})

baro_api(skey, res_id, encode)
# Out:
#      bizesId       bizesNm     brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   10358206          송월타월      대상대리점          D         소매        D03
# 1   10385826          금광상회                     D         소매        D03
# 2   10481487   국립중앙의료원장례식장       장례식장          F      생활서비스        F18
# 3   10647133        화신종합목재                     D         소매        D21
# 4   11000112       종오직업소개소                     F      생활서비스        F05
# 5   11154682         신신지업사                     D         소매        D07
# 6   11178655           우연사                     D         소매        D05
# 7   11748018          참치명인                     Q         음식        Q03
# 8   11749666   필스테이동대문이코노미    동대문이코노미          O         숙박        O02
# 9   11789073         종로완구사                     D         소매        D03
# 10  11797847  담소사골순대종로5가역점     종로5가역점          Q         음식        Q10
# 11  11800209       현대시티아울렛       동대문점          D         소매        D03
# ...

# %% [markdown]
# #### 0728_4 과제사각형 내 상권조회

# %%
res_id = 'storezone'


encode = urlencode({quote_plus('catId'):'rectangle', quote_plus('minx'):'126.978020', quote_plus('miny'):'37.557825', quote_plus('maxx'):'126.987732', quote_plus('maxy'):'37.562022'})

baro_api(skey, res_id, encode)
# Out:
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9191      남대문시장       11    서울특별시    11140       중구    111020        27
# 1    9196        명동역       11    서울특별시    11140       중구     96649        28
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((126.976451547074 37.5576325944...  2021-06-30
# 1  MULTIPOLYGON (((126.983476244148 37.5605598377...  2021-06-30

# %% [markdown]
# #### 0728_5 행정단위 상권조회

# %%
res_id = 'storezone'

encode = urlencode({quote_plus('catId'):'dong', quote_plus('divId'):'adongCd', quote_plus('key'):'1168069000'})

baro_api(skey, res_id, encode)
# Out:
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9324      포이사거리       11    서울특별시    11680      강남구     14033        33
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.044811833677 37.4781705036...  2021-06-30

# %% [markdown]
# ## 상가업소 조회

# %% [markdown]
# ### 행정동 단위 상사업소 조회

# %%
res_id = 'store'
    
encode = urlencode({quote_plus('catId'):'dong', quote_plus('divId'):'ctprvnCd', quote_plus('key'):'11'})

baro_api(skey, res_id, encode)
# Out:
#      bizesId     bizesNm  brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   10001387      이음스튜디오                  D         소매        D18
# 1   10004623      이철헤어커커    상계역점          F      생활서비스        F01
# 2   10016187        일조산업                  D         소매        D07
# 3   10030788      장안순대국밥                  Q         음식        Q10
# 4   10031349         장어야    동자동점          Q         음식        Q01
# 5   10031436        장어천국                  Q         음식        Q01
# 6   10034303        재건공조                  D         소매        D07
# 7   10034977        재진패션                  D         소매        D05
# 8   10038561   전자랜드프라이스킹     은평점          D         소매        D12
# 9   10041487         정관장   서대문역점          D         소매        D03
# 10  10041503         정관장   남부법원점          D         소매        D10
# 11  10050747       제시카키친  이대하늬솔점          Q         음식        Q06
# 12  10056742      제일전기조명                  D         소매        D07
# ...
